# %% [markdown]
# # Fraud Analytics & AI Intelligence System
# ## Exploratory Data Analysis (EDA)
#
# This notebook runs the core data analysis pipeline, generating insights on fraud patterns including:
# - Transaction amount distribution
# - Time-based fraud trends
# - Location-based fraud
# - Merchant category analysis

# %%
import sys
from pathlib import Path
sys.path.append(str(Path.cwd().parent))

from src.eda_analysis import run_eda

# %%
# Run full EDA and generate charts in the dashboard/ folder
summary = run_eda(nrows=200000)
print("\n--- Key Insights ---")
print(f"Fraud percentage: {summary['fraud_percentage']}%")
print(f"Peak fraud hour: {summary['peak_fraud_hour']}:00")
